# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("../data/main_data/2022-06/2022-06-avon-and-somerset-street.csv") # I only took one set of data.

# %%
types = np.unique(data['Crime type']) # The punishment data are all from goverment site of UK.

# %%
types
# Out:
# array(['Anti-social behaviour', 'Bicycle theft', 'Burglary',
#        'Criminal damage and arson', 'Drugs', 'Other crime', 'Other theft',
#        'Possession of weapons', 'Public order', 'Robbery', 'Shoplifting',
#        'Theft from the person', 'Vehicle crime',
#        'Violence and sexual offences'], dtype=object)

# %%
weight = dict(Anti_social = 0.1
Bicycle_theft = 3
Burglary = 12
CDA = 20
Drugs = 10
Possession_of_weapons = 0.5
Public_order = 0.5
Robbery = 20
Shoplifting = 2
Theft_fro_the_person = 7
Vehicle_crime = 5
Violence_sexual_offences = 20
Other_theft = 5
Other_crime = 5)

# %%
# https://www.gov.uk/civil-injunctions-criminal-behaviour-orders
# Anti-social behaviour : Only a notice or an order as punishment.

# %%
# https://www.legislation.gov.uk/ukpga/1968/60/section/12/enacted?view=plain
# Bicycle theft: be liable to imprisonment for a term not exceeding three years.

# %%
# https://www.legislation.gov.uk/ukpga/1968/60/crossheading/theft-robbery-burglary-etc
# A person guilty of burglary shall on conviction on indictment be liable to imprisonment for a term not exceeding—

#(a)where the offence was committed in respect of a building or part of a building which is a dwelling, fourteen years;

#(b)in any other case, ten years.
 # (14+10)/2

# %%
# https://www.cps.gov.uk/legal-guidance/criminal-damage
# https://www.legislation.gov.uk/ukpga/1971/48
# Section 4 CDA 1971 sets out 
#a maximum penalty of life imprisonment for aggravated criminal damage and aggravated arson.
 # ?

# %%
# https://www.gov.uk/penalties-drug-possession-dealing
# The situation of drugs is complex because it's depending on what kind of drugs you take and if you just own or supplimenting.

# %% [markdown]
# ![994215EA-79A9-40C8-80AB-C20F55564FB2.png](attachment:994215EA-79A9-40C8-80AB-C20F55564FB2.png)

# %%
# https://www.cps.gov.uk/legal-guidance/firearms
# Possession of weapons = 6 mounths r a fine of £200. or both.

# %%
#  https://www.legislation.gov.uk/ukpga/1986/64 
#  Public order  : Maximum sentence of 6 months imprisonment and a fine

# %%
# https://www.cps.gov.uk/legal-guidance/theft-act-offences
# Robbery is indictable only, punishable with life imprisonment or an unlimited fine or both.

# %%
# https://www.sentencingcouncil.org.uk/outlines/shoplifting/
#If the goods are worth less than £200, the maximum sentence is six months’ custody.
#If the goods are worth more than £200, the maximum sentence is seven years’ custody.

# %%
# https://www.cps.gov.uk/legal-guidance/theft-act-offences
# Theft is triable either-way with a maximum penalty in the Crown Court of seven years imprisonment and/or an unlimited fine.

# %%
# https://www.police.uk/advice/advice-and-information/rs/road-safety/driving-offences/
#The penalties for causing death by dangerous driving are one to 14 years in prison, and a driving ban for a minimum of two years.
#The penalties for causing death by careless or inconsiderate driving are up to 5 years in prison, and a driving ban for a minimum of one year.
#The penalties for causing death by driving whilst unlicensed, uninsured or disqualified are up to two years in prison, an unlimited fine, or both, and a driving ban for a minimum of one year.

# %%
# https://www.cps.gov.uk/crime-info/violent-crime

# %% [markdown]
# ![AA93269753FCA30B92D97DFDAD281DDC.png](attachment:AA93269753FCA30B92D97DFDAD281DDC.png)
